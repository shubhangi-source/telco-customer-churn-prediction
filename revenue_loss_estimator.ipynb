# %%
import pandas as pd
#load data
df=pd.read_csv("customer_retention_results.csv")
df
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  Churn  \
# 0                 0       1           29.85         29.85      0
# 1                 0      34           56.95       1889.50      0
# 2                 0       2           53.85        108.15      1
# 3                 0      45           42.30       1840.75      0
# 4                 0       2           70.70        151.65      1
# ...             ...     ...             ...           ...    ...
# 7038              0      24           84.80       1990.50      0
# 7039              0      72          103.20       7362.90      0
# 7040              0      11           29.60        346.45      0
# 7041              1       4           74.40        306.60      1
# 7042              0      66          105.65       6844.50      0
#
#       AverageMonthlySpend  gender_Male  Partner_Yes  Dependents_Yes  \
# 0               14.925000            0            1               0
# 1               53.985714            1            0               0
# 2               36.050000            1            0               0
# 3               40.016304            1            0               0
# 4               50.550000            0            0               0
# ...                   ...          ...          ...             ...
# 7038            79.620000            1            1               1
# 7039           100.861644            0            1               1
# 7040            28.870833            0            1               1
# 7041            61.320000            1            1               0
# 7042           102.156716            1            0               0
#
#       PhoneService_Yes  ...  Contract_One year  Contract_Two year  \
# 0                    0  ...                  0                  0
# 1                    1  ...                  1                  0
# 2                    1  ...                  0                  0
# 3                    0  ...                  1                  0
# 4                    1  ...                  0                  0
# ...                ...  ...                ...                ...
# 7038                 1  ...                  1                  0
# 7039                 1  ...                  1                  0
# 7040                 0  ...                  0                  0
# 7041                 1  ...                  0                  0
# 7042                 1  ...                  0                  1
#
#       PaperlessBilling_Yes  PaymentMethod_Credit card (automatic)  \
# 0                        1                                      0
# 1                        0                                      0
# 2                        1                                      0
# 3                        0                                      0
# 4                        1                                      0
# ...                    ...                                    ...
# 7038                     1                                      0
# 7039                     1                                      1
# 7040                     1                                      0
# 7041                     1                                      0
# 7042                     1                                      0
#
#       PaymentMethod_Electronic check  PaymentMethod_Mailed check  \
# 0                                  1                           0
# 1                                  0                           1
# 2                                  0                           1
# 3                                  0                           0
# 4                                  1                           0
# ...                              ...                         ...
# 7038                               0                           1
# 7039                               0                           0
# 7040                               1                           0
# 7041                               0                           1
# 7042                               0                           0
#
#       predicted_churn  Churn_Probability         Customer_Grade  \
# 0                   1           0.744940  Grade C (Medium Risk)
# 1                   0           0.112391         Grade E (Safe)
# 2                   1           0.718995  Grade C (Medium Risk)
# 3                   0           0.083161         Grade E (Safe)
# 4                   1           0.839914    Grade B (High Risk)
# ...               ...                ...                    ...
# 7038                0           0.247044         Grade E (Safe)
# 7039                0           0.254907         Grade E (Safe)
# 7040                1           0.520530  Grade C (Medium Risk)
# 7041                1           0.852560    Grade B (High Risk)
# 7042                0           0.317288     Grade D (Low Risk)
#
#              Retention_Action
# 0          Offer 10% Discount
# 1          No Action Required
# 2          Offer 10% Discount
# 3          No Action Required
# 4          Offer 15% Discount
# ...                       ...
# 7038       No Action Required
# 7039       No Action Required
# 7040       Offer 10% Discount
# 7041       Offer 15% Discount
# 7042  Send Personalized Email
#
# [7043 rows x 36 columns]

# %%
# Revenue at risk for each customer
df["Revenue_At_Risk"]=(df["MonthlyCharges"]*df["Churn_Probability"])

# %%
#total expected monthly revenue loss
total_loss=df['Revenue_At_Risk'].sum()
print(f"Total Expected Monthly Revenue Loss:${total_loss}")

# %%
#find the top 10 customers by revenue at risk:
top_10=df.sort_values(by='Revenue_At_Risk',ascending=False).head(10)
print(top_10[
    [
        "MonthlyCharges",
        "Churn_Probability",
        "Revenue_At_Risk",
        "Retention_Action"
    ]
])
# Out:
#       MonthlyCharges  Churn_Probability  Revenue_At_Risk  \
# 6482          101.45           0.939468        95.309028
# 5933          105.00           0.907224        95.258469
# 2208          100.80           0.943203        95.074880
# 4826          105.50           0.894883        94.410122
# 1026          100.60           0.926424        93.198214
# 3871          101.55           0.915746        92.993960
# 905           100.50           0.923546        92.816416
# 171           104.40           0.888354        92.744198
# 6385          101.70           0.911643        92.714140
# 6894          105.90           0.874574        92.617336
#
#                           Retention_Action
# 6482  Offer 20% Discount + Premium Support
# 5933  Offer 20% Discount + Premium Support
# 2208  Offer 20% Discount + Premium Support
# 4826                    Offer 15% Discount
# 1026  Offer 20% Discount + Premium Support
# 3871  Offer 20% Discount + Premium Support
# 905   Offer 20% Discount + Premium Support
# 171                     Offer 15% Discount
# 6385  Offer 20% Discount + Premium Support
# 6894                    Offer 15% Discount

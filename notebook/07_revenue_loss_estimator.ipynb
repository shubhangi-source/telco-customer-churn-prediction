# %%
import pandas as pd
df=pd.read_csv("../data/customer_retention_result.csv")

# %% [markdown]
# # Revenue at risk for each customer

# %%
df["Revenue_At_Risk"]=(df["MonthlyCharges"]*df["Churn_Probability"])

# %% [markdown]
# # total expected monthly revenue loss

# %%
total_loss=df['Revenue_At_Risk'].sum()
print(f"Total Expected Monthly Revenue Loss:${total_loss}")
# Out:
# Total Expected Monthly Revenue Loss:$209502.77228722768

# %% [markdown]
# # find the top 10 customers by revenue at risk:

# %%
top_10=df.sort_values(by='Revenue_At_Risk',ascending=False).head(10)
print(top_10[
    [
        "MonthlyCharges",
        "Churn_Probability",
        "Revenue_At_Risk",
        "Retention_Action"
    ]
])
# Out:
#       MonthlyCharges  Churn_Probability  Revenue_At_Risk  \
# 5933          105.00           0.939129        98.608524
# 6482          101.45           0.967173        98.119719
# 6894          105.90           0.923424        97.790623
# 2208          100.80           0.968150        97.589533
# 3956          105.30           0.925153        97.418644
# 2246          102.45           0.941655        96.472512
# 1704           99.75           0.957370        95.497643
# 171           104.40           0.914591        95.483327
# 4459          100.25           0.949703        95.207732
# 1568          111.40           0.850629        94.760097
#
#                             Retention_Action
# 5933  Welcome Back Offer + Free Installation
# 6482  Welcome Back Offer + Free Installation
# 6894  Welcome Back Offer + Free Installation
# 2208  Welcome Back Offer + Free Installation
# 3956  Welcome Back Offer + Free Installation
# 2246  Welcome Back Offer + Free Installation
# 1704  Welcome Back Offer + Free Installation
# 171   Welcome Back Offer + Free Installation
# 4459  Welcome Back Offer + Free Installation
# 1568  Welcome Back Offer + Free Installation

# %% [markdown]
# # Save Revenue Loss Estimator results

# %%
df.to_csv("revenue_loss_estimator.csv", index=False)

print("Revenue Loss Estimator saved successfully!")
df
# Out:
# Revenue Loss Estimator saved successfully!
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# 1                   No             DSL            Yes           No  ...
# 2                   No             DSL            Yes          Yes  ...
# 3     No phone service             DSL            Yes           No  ...
# 4                   No     Fiber optic             No           No  ...
# ...                ...             ...            ...          ...  ...
# 7038               Yes             DSL            Yes           No  ...
# 7039               Yes     Fiber optic             No          Yes  ...
# 7040  No phone service             DSL            Yes           No  ...
# 7041               Yes     Fiber optic             No           No  ...
# 7042                No     Fiber optic            Yes           No  ...
#
#      AverageMonthlySpend Churn predicted_churn Churn_Probability      CLV  \
# 0              14.925000     0               1          0.798758    29.85
# 1              53.985714     0               0          0.105886  1936.30
# 2              36.050000     1               1          0.548263   107.70
# 3              40.016304     0               0          0.084320  1903.50
# 4              50.550000     1               1          0.869592   141.40
# ...                  ...   ...             ...               ...      ...
# 7038           79.620000     0               0          0.246825  2035.20
# 7039          100.861644     0               0          0.329575  7430.40
# 7040           28.870833     0               1          0.557914   325.60
# 7041           61.320000     1               1          0.842372   297.60
# 7042          102.156716     0               0          0.127665  6972.90
#
#      Priority_Score Priority_Level  \
# 0             56.02         Medium
# 1             14.21            Low
# 2             38.76            Low
# 3             12.58            Low
# 4             61.37           High
# ...             ...            ...
# 7038          24.42            Low
# 7039          49.14         Medium
# 7040          40.20         Medium
# 7041          60.01           High
# 7042          33.40            Low
#
#                                   Recommendation_Reason  \
# 0                           Customer is relatively new.
# 1                Customer currently has low churn risk.
# 2                Customer currently has low churn risk.
# 3                Customer currently has low churn risk.
# 4     Customer is still in the early stage of the re...
# ...                                                 ...
# 7038             Customer currently has low churn risk.
# 7039      Customer has relatively high monthly charges.
# 7040                        Customer is relatively new.
# 7041  Customer is still in the early stage of the re...
# 7042  Customer is highly valuable and currently has ...
#
#                             Retention_Action  Revenue_At_Risk
# 0         Welcome Offer + Personalized Email        23.842937
# 1                  Regular Promotional Email         6.030207
# 2                  Regular Promotional Email        29.523938
# 3                  Regular Promotional Email         3.566734
# 4     Welcome Back Offer + Free Installation        61.480168
# ...                                      ...              ...
# 7038               Regular Promotional Email        20.930727
# 7039            10% Discount on Monthly Bill        34.012122
# 7040      Welcome Offer + Personalized Email        16.514258
# 7041  Welcome Back Offer + Free Installation        62.672488
# 7042                     VIP Loyalty Rewards        13.487793
#
# [7043 rows x 29 columns]
